# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
median_age_by_sex_class = df.groupby(['Sex', 'Pclass'])['Age'].median().reset_index()

# %%
df1 = df[df['Age'].isna()].merge(median_age_by_sex_class, how='left', on=['Sex', 'Pclass'])
df1.drop(columns='Age_x', inplace=True)
df1.rename(columns={'Age_y': 'Age'}, inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              6         0       3                          Moran, Mr. James
# 1             18         1       2              Williams, Mr. Charles Eugene
# 2             20         1       3                   Masselmani, Mrs. Fatima
# 3             27         0       3                   Emir, Mr. Farred Chehab
# 4             29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 172          860         0       3                          Razi, Mr. Raihed
# 173          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 174          869         0       3               van Melkebeke, Mr. Philemon
# 175          879         0       3                        Laleff, Mr. Kristo
# 176          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df2 = df.dropna(subset=['Age'])
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_pred = pd.concat([df1,df2]).sort_values(by='PassengerId').reset_index(drop=True)
df_pred
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df_act = df.fillna(value=0)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(df_act['Age'], df_pred['Age'])
mse = mean_squared_error(df_act['Age'], df_pred['Age'])
r2 = r2_score(df_act['Age'], df_pred['Age'])

print(f"MAE: {mae:.3f}")
print(f"MSE: {mse:.3f}")
print(f"R²: {r2:.3f}")
# Out:
# MAE: 5.313
# MSE: 148.662
# R²: 0.519
